# %%
import pandas as pd
import numpy as np
import matplotlib . pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Raj Sinha\OneDrive\Desktop\super_market 1.csv")
df.head()
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product_line  Unit_price  Quantity      Tax     Total    month  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  janaury
# 1  Electronic accessories       15.28         5   3.8200   80.2200  janaury
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  janaury
# 3       Health and beauty       58.22         8  23.2880  489.0480  janaury
# 4       Sports and travel       86.31         7  30.2085  634.3785  janaury
#
#        Payment    cogs  gross_margin_ percentage  gross_income  Rating
# 0      Ewallet  522.83                  4.761905       26.1415     9.1
# ...

# %%
# data cleaning
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Invoice ID                1000 non-null   object
#  1   Branch                    1000 non-null   object
#  2   City                      1000 non-null   object
#  3   Customer_type             1000 non-null   object
#  4   Gender                    1000 non-null   object
#  5   Product_line              1000 non-null   object
#  6   Unit_price                1000 non-null   float64
#  7   Quantity                  1000 non-null   int64
#  8   Tax                       1000 non-null   float64
#  9   Total                     1000 non-null   float64
#  10  month                     1000 non-null   object
#  11  Payment                   1000 non-null   object
#  12  cogs                      1000 non-null   float64
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
# basic info
df.shape
# Out:
# (1000, 16)

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer_type', 'Gender',
#        'Product_line', 'Unit_price', 'Quantity', 'Tax', 'Total', 'month',
#        'Payment', 'cogs', 'gross_margin_ percentage', 'gross_income',
#        'Rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Invoice ID                1000 non-null   object
#  1   Branch                    1000 non-null   object
#  2   City                      1000 non-null   object
#  3   Customer_type             1000 non-null   object
#  4   Gender                    1000 non-null   object
#  5   Product_line              1000 non-null   object
#  6   Unit_price                1000 non-null   float64
#  7   Quantity                  1000 non-null   int64
#  8   Tax                       1000 non-null   float64
#  9   Total                     1000 non-null   float64
#  10  month                     1000 non-null   object
#  11  Payment                   1000 non-null   object
#  12  cogs                      1000 non-null   float64
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Invoice ID Branch       City Customer_type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product_line  Unit_price  Quantity      Tax      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# data cleaning
df.isnull().sum()
# Out:
# Invoice ID                  0
# Branch                      0
# City                        0
# Customer_type               0
# Gender                      0
# Product_line                0
# Unit_price                  0
# Quantity                    0
# Tax                         0
# Total                       0
# month                       0
# Payment                     0
# cogs                        0
# gross_margin_ percentage    0
# gross_income                0
# Rating                      0
# dtype: int64

# %%
# basic analysis
df['Total'].sum()
# Out:
# np.float64(322966.749)

# %%
df['Total'].mean()
# Out:
# np.float64(322.966749)

# %%
df['Quantity'].sum()
# Out:
# np.int64(5510)

# %%
# group by queries
df.groupby('City')
['Total'].sum().sort_values(ascending=
False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 # group by queries
#       2 df.groupby('City')
# ----> 3 ['Total'].max().sort_values(ascending=
#       4 False)
#
# AttributeError: 'list' object has no attribute 'max'

# %%
df.groupby('Branch')['Total'].sum()
# Out:
# Branch
# A    106200.3705
# B    106197.6720
# C    110568.7065
# Name: Total, dtype: float64

# %%
df.groupby('Gender')['Total'].sum()
# Out:
# Gender
# Female    167882.925
# Male      155083.824
# Name: Total, dtype: float64

# %%
df['Payment'].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %%
df.loc[df['Total'].idxmax()]
# Out:
# Invoice ID                          860-79-0874
# Branch                                        C
# City                                  Naypyitaw
# Customer_type                            Member
# Gender                                   Female
# Product_line                Fashion accessories
# Unit_price                                 99.3
# Quantity                                     10
# Tax                                       49.65
# Total                                   1042.65
# month                                   october
# Payment                             Credit card
# cogs                                      993.0
# gross_margin_ percentage               4.761905
# gross_income                              49.65
# Rating                                      6.6
# Name: 350, dtype: object

# %%
df.nlargest(5,'Total')
# Out:
#       Invoice ID Branch       City Customer_type  Gender         Product_line  \
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
# 167  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 557  283-26-5248      C  Naypyitaw        Member  Female   Food and beverages
# 699  751-41-9720      C  Naypyitaw        Normal    Male   Home and lifestyle
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
#
#      Unit_price  Quantity    Tax    Total      month      Payment   cogs  \
# 350       99.30        10  49.65  1042.65    october  Credit card  993.0
# 167       98.98        10  49.49  1039.29    janaury  Credit card  989.8
# 557       98.52        10  49.26  1034.46      april      Ewallet  985.2
# 699       97.50        10  48.75  1023.75   november      Ewallet  975.0
# 996       97.38        10  48.69  1022.49  september      Ewallet  973.8
#
#      gross_margin_ percentage  gross_income  Rating
# ...

# %%
df.groupby('City')['gross_income'].sum()
# Out:
# City
# Mandalay     5057.0320
# Naypyitaw    5265.1765
# Yangon       5057.1605
# Name: gross_income, dtype: float64

# %%
df.groupby('Customer_type')['Total'].sum()
# Out:
# Customer_type
# Member    164223.444
# Normal    158743.305
# Name: Total, dtype: float64

# %%
df.loc[df['Total'].idxmax()]
# Out:
# Invoice ID                          860-79-0874
# Branch                                        C
# City                                  Naypyitaw
# Customer_type                            Member
# Gender                                   Female
# Product_line                Fashion accessories
# Unit_price                                 99.3
# Quantity                                     10
# Tax                                       49.65
# Total                                   1042.65
# month                                   october
# Payment                             Credit card
# cogs                                      993.0
# gross_margin_ percentage               4.761905
# gross_income                              49.65
# Rating                                      6.6
# Name: 350, dtype: object

# %%
# visualisation 
df.groupby('City')
['Total'].sum().plot(kind ='bar')
plt.tittle("sales by city")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 3
#       1 # visualisation
#       2 df.groupby('City')
# ----> 3 ['Total'].sum().plot(kind ='bar')
#       4 plt.tittle("sales by city")
#       5 plt.show()
#
# AttributeError: 'list' object has no attribute 'sum'

# %%
sns.barplot(x='Total',y='Product_line',data=df)
plt.show()

# %%
df['Gender'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.show()

# %%
df.groupby('Month')
['Total'].sum().plot()
plt.title("monthly sales trend")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df.groupby('Month')
#       2 ['Total'].sum().plot()
#       3 plt.title("monthly sales trend")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# ...

# %%
df[['City','Product_line']]
# Out:
#           City            Product_line
# 0       Yangon       Health and beauty
# 1    Naypyitaw  Electronic accessories
# 2       Yangon      Home and lifestyle
# 3       Yangon       Health and beauty
# 4       Yangon       Sports and travel
# ..         ...                     ...
# 995  Naypyitaw       Health and beauty
# 996   Mandalay      Home and lifestyle
# 997     Yangon      Food and beverages
# 998     Yangon      Home and lifestyle
# 999     Yangon     Fashion accessories
#
# [1000 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Invoice ID                  0
# Branch                      0
# City                        0
# Customer_type               0
# Gender                      0
# Product_line                0
# Unit_price                  0
# Quantity                    0
# Tax                         0
# Total                       0
# month                       0
# Payment                     0
# cogs                        0
# gross_margin_ percentage    0
# gross_income                0
# Rating                      0
# dtype: int64

# %%
df.dropna()
# Out:
#       Invoice ID Branch       City Customer_type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product_line  Unit_price  Quantity      Tax      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.fillna(0)
# Out:
#       Invoice ID Branch       City Customer_type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product_line  Unit_price  Quantity      Tax      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'city'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ...

# %%
df.sort_values(by='gross_income',ascending=False)
# Out:
#       Invoice ID Branch       City Customer_type  Gender         Product_line  \
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
# 167  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 557  283-26-5248      C  Naypyitaw        Member  Female   Food and beverages
# 699  751-41-9720      C  Naypyitaw        Normal    Male   Home and lifestyle
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# ..           ...    ...        ...           ...     ...                  ...
# 402  236-86-3015      C  Naypyitaw        Member    Male   Home and lifestyle
# 443  192-98-7397      C  Naypyitaw        Normal    Male  Fashion accessories
# 223  279-62-1445      C  Naypyitaw        Member  Female  Fashion accessories
# 629  308-39-1707      A     Yangon        Normal  Female  Fashion accessories
# 822  784-21-9238      C  Naypyitaw        Member    Male    Sports and travel
#
# ...

# %%
#merge
pd.merge(df1.df2,on ='customer id',how='inner')

# %%
# value counts and unique
df['City'].value_counts()
# Out:
# City
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %%
df['City'].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df['City'].nunique()
# Out:
# 3

# %%
df['gross_margin_percentage'].apply(lambda x: x*2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gross_margin_percentage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ...

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.corr()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
#    2000     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df.groupby('Product_line')
['Total'].sum().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 df.groupby('Product_line')
# ----> 2 ['Total'].sum().sort_values(ascending=False)
#
# AttributeError: 'list' object has no attribute 'sum'

# %%
df['Product_line'].value_counts()
# Out:
# Product_line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %%
df.groupby('Product_line')['Total'].sum()
# Out:
# Product_line
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Food and beverages        56144.8440
# Health and beauty         49193.7390
# Home and lifestyle        53861.9130
# Sports and travel         55122.8265
# Name: Total, dtype: float64

# %%
pd.pivot_table(df,
               values='Total',
               index='City',
               columns='Product_line',
               aggfunc='sum')
# Out:
# Product_line  Electronic accessories  Fashion accessories  Food and beverages  \
# City
# Mandalay                  17051.4435           16413.3165          15214.8885
# Naypyitaw                 18968.9745           21560.0700          23766.8550
# Yangon                    18317.1135           16332.5085          17163.1005
#
# Product_line  Health and beauty  Home and lifestyle  Sports and travel
# City
# Mandalay              19980.660          17549.1645         19988.1990
# Naypyitaw             16615.326          13895.5530         15761.9280
# Yangon                12597.753          22417.1955         19372.6995

# %%
pd.pivot_table(df,
               values='Total',
               index='City',
               columns='Product_line',
               aggfunc='max')
# Out:
# Product_line  Electronic accessories  Fashion accessories  Food and beverages  \
# City
# Mandalay                    942.4485              874.125             888.615
# Naypyitaw                   864.5700             1042.650            1034.460
# Yangon                      931.0350             1039.290             932.337
#
# Product_line  Health and beauty  Home and lifestyle  Sports and travel
# City
# Mandalay                922.635            1022.490           944.6220
# Naypyitaw               950.250            1023.750          1002.1200
# Yangon                  752.640             951.825           926.9505

# %%
city_sales=df.groupby('City')['Total'].sum()
plt.figure()
city_sales.plot(kind='bar')
plt.title("Total sales by city")
plt.xlabel("City")
plt.ylabel("Total")
plt.show()

# %%
payment = df['Payment'].value_counts()

plt.figure()
payment.plot(kind='pie',autopct='%1.1f%%')
plt.title("payment method")
plt.ylabel('')
plt.show()

# %%
branch_profit = df.groupby('Branch')['gross_income'].sum()

plt.figure()
branch_profit.plot(kind='bar')
plt.title("profit by branch")
plt.xlabel("Branch")
plt.ylabel("gross_income")
plt.show()

# %%
gender_total = df.groupby('Gender')['Total'].sum()

plt.figure()
gender_total.plot(kind='bar')
plt.title("gender by total")
plt.xlabel("Gender")
plt.ylabel("Total")
plt.show()
